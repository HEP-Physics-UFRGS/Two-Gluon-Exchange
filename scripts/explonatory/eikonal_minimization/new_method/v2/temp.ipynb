# %%
import math

def chi2(b):
    # Função simples para teste (igual ao Fortran)
    return complex(b, 0.0)

def executar_programa_chi():

    sqrt_s = 7000.0
    s = sqrt_s * sqrt_s
    epsabs = 1e-3

    bmin = 0.0
    bmax = 10.0
    b = 0.0
    tt = 0.0

    pi = math.pi

    amp_eik = 0.0 + 0.0j

    while True:
        while True:
            resultado = chi2(b)
            amp_eik = amp_eik + resultado

            print(b, amp_eik)

            b = b + 1.0
            if b <= bmax:
                pass
            else:
                break

        print(tt, amp_eik, "----------------------------------")

        diff = (abs(amp_eik)**2)**0.389379323
        diff = diff / (16.0 * pi * s * s)

        tt = tt + epsabs

        amp_eik = 0.0 + 0.0j
        b = 0.0

        if tt <= 0.1:
            pass
        else:
            break

if __name__ == "__main__":
    executar_programa_chi()
# Out:
# 0.0 0j
# 1.0 (1+0j)
# 2.0 (3+0j)
# 3.0 (6+0j)
# 4.0 (10+0j)
# 5.0 (15+0j)
# 6.0 (21+0j)
# 7.0 (28+0j)
# 8.0 (36+0j)
# 9.0 (45+0j)
# 10.0 (55+0j)
# 0.0 (55+0j) ----------------------------------
# 0.0 0j
# 1.0 (1+0j)
# 2.0 (3+0j)
# 3.0 (6+0j)
# 4.0 (10+0j)
# 5.0 (15+0j)
# 6.0 (21+0j)
# 7.0 (28+0j)
# 8.0 (36+0j)
# 9.0 (45+0j)
# 10.0 (55+0j)
# 0.001 (55+0j) ----------------------------------
# 0.0 0j
# 1.0 (1+0j)
# 2.0 (3+0j)
# 3.0 (6+0j)
# 4.0 (10+0j)
# 5.0 (15+0j)
# 6.0 (21+0j)
# 7.0 (28+0j)
# 8.0 (36+0j)
# 9.0 (45+0j)
# 10.0 (55+0j)
# 0.002 (55+0j) ----------------------------------
# 0.0 0j
# 1.0 (1+0j)
# 2.0 (3+0j)
# 3.0 (6+0j)
# 4.0 (10+0j)
# 5.0 (15+0j)
# 6.0 (21+0j)
# 7.0 (28+0j)
# 8.0 (36+0j)
# 9.0 (45+0j)
# 10.0 (55+0j)
# 0.003 (55+0j) ----------------------------------
# 0.0 0j
# 1.0 (1+0j)
# 2.0 (3+0j)
# 3.0 (6+0j)
# 4.0 (10+0j)
# 5.0 (15+0j)
# 6.0 (21+0j)
# 7.0 (28+0j)
# 8.0 (36+0j)
# 9.0 (45+0j)
# 10.0 (55+0j)
# 0.004 (55+0j) ----------------------------------
# 0.0 0j
# ...
